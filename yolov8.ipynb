# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# ...
# 100% 165k/165k [00:00<00:00, 6.30MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 196.0ms
# Speed: 4.1ms preprocess, 196.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Install required packages
# !pip install torch torchvision

# %%
train: "/content/drive/My Drive/dataset/train/images"
val: "/content/drive/My Drive/dataset/valid/images"
test: "/content/drive/My Drive/dataset/test/images"
train_labels: "/content/drive/My Drive/dataset/train/labelTxt"
val_labels: "/content/drive/My Drive/dataset/valid/labelTxt"
test_labels: "/content/drive/My Drive/dataset/test/labelTxt"
nc: 4  # Number of classes
names: ['angle', 'messed_up_angle', 'fracture', 'line']

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=yolov8n.pt data=/content/drive/My\ Drive/dataset/data.yaml imgsz = 416 --batch =16 --epochs =500 --project= /content/drive/My\ Drive/dataset/runs
# Out:
# WARNING ⚠️ '--batch=16' does not require leading dashes '--', updating to 'batch=16'.
# WARNING ⚠️ '--epochs=500' does not require leading dashes '--', updating to 'epochs=500'.
# WARNING ⚠️ '--project=/content/drive/My Drive/dataset/runs' does not require leading dashes '--', updating to 'project=/content/drive/My Drive/dataset/runs'.
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo val model=yolov8n.pt data= /content/drive/My\ Drive/dataset/data.yaml project= /content/drive/My\ Drive/dataset/runs
# Out:
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
# val: Scanning /content/drive/My Drive/dataset/valid/labels.cache... 88 images, 5 backgrounds, 0 corrupt: 100% 88/88 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [00:05<00:00,  1.18it/s]
#                    all         88        117          0          0          0          0
# Speed: 4.2ms preprocess, 24.1ms inference, 0.0ms loss, 10.2ms postprocess per image
# Results saved to /content/drive/My Drive/dataset/runs/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo predict model=yolov8n.pt source="/content/drive/My Drive/dataset/test/images" project= /content/drive/My\ Drive/dataset/runs
# Out:
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/44 /content/drive/My Drive/dataset/test/images/105_jpg.rf.3cde2fcd15a9bdf6a2d2d32aff48f33d.jpg: 640x384 1 vase, 113.3ms
# image 2/44 /content/drive/My Drive/dataset/test/images/10_jpg.rf.d362a00f9a6b4ac31668dc8aae9c71de.jpg: 640x640 1 person, 8.6ms
# image 3/44 /content/drive/My Drive/dataset/test/images/117_jpg.rf.119dccd2483b04d8d3a8c33a1393d362.jpg: 640x224 (no detections), 63.1ms
# image 4/44 /content/drive/My Drive/dataset/test/images/118_jpg.rf.acee2a86eba65adc57f3b15d5acab93c.jpg: 640x256 1 toothbrush, 73.8ms
# image 5/44 /content/drive/My Drive/dataset/test/images/11_jpg.rf.8e1c22ba2779121f3ba0a8ae03a20407.jpg: 640x384 (no detections), 7.0ms
# image 6/44 /content/drive/My Drive/dataset/test/images/124_jpg.rf.100aeaede7a9c017d7f74f73cfcf34d7.jpg: 640x544 (no detections), 63.2ms
# ...
